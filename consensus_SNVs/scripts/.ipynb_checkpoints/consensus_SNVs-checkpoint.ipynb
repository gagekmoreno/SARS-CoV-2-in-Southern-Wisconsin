# %% [markdown]
# # Single nucleotide variants (SNVs)
#
# **Author**: Katarina Braun
#
#
# ## Overview
#
# This script maps fasta files (contains the consensus sequence generated from the ARTIC analysis pipeline) to the Wuhan/1 reference (MT039887), generates an alignment file (bam), sorts the bam (sam), generates a pileup file, and calls variants (any position that differs from the reference) using Varscan. The resulting VCF files contain consensus SNVs only.
#
# This script cleans up the VCF files and saves each VCF as a new, smaller CSV.
#
# This script also generates two figures:
# 1. Consensus SNVs vs # of sequences figure.
# 2. Number of sequences within age bins
#
# ## Input:
#
# Consensus fasta files:
#
# `data_raw/UWHC/*.fasta`
#     - 122 files
# `data_raw/MHD/*.fasta`
#     - 125 files
#
#
# ## Output:
#
# Consensus SNV output files:
#
# `data_derived/UWHC/VCFs/*.vcfs`
#     - 122 files
# `data_derived/UWHC/VCFs/*.vcfs`
#     - 125 files
#
# Figures:
# 1. `figures/consensus_SNV_differences.pdf`
# 2. `figures/SNVs_vs_age.pdf`
# 3. `figures/SNVs-per-age-bins.pdf`

# %% [markdown]
# ## import modules and dependencies

# %%
import pandas as pd
import glob, os
import shutil as sh
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl
from pandas.plotting import table
from statistics import mean
import statistics

# %% [markdown]
# ## map reads, modify alignment file, call consensus SNVs

# %%
# %%bash
#
# # UWHC samples, this takes ~10 mins to run
#
# for file in $(ls ../data_raw/UWHC/*.fasta)
# do
#     bbmap.sh in=$file out=$file.bam ref=ref.fa #map to Wuhan reference
#     samtools sort $file.bam -o $file.bam # sort the bam
#     samtools mpileup -f ref.fa $file.bam > $file.pileup # generate a pileup file
#     java -jar VarScan.jar pileup2snp $file.pileup --min-coverage 1 --min-reads2 1 > $file.vcf
# done
#
# ##
# Out:
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-02_2020.fasta out=../data_raw/UWHC/USA_WI-UW-02_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-02_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-02_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.784 seconds.
# Analyzed Index:   	3.321 seconds.
# Found samtools 1.9
# Started output stream:	0.105 seconds.
# Cleared Memory:    	0.112 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.346 seconds.
# Reads/sec:       	173.55
# kBases/sec:      	86.14
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 86.6667% 	       52 	 87.3011% 	       26000
# semiperfect site:	 86.6667% 	       52 	 87.3011% 	       26000
#
# Match Rate:      	      NA 	       NA 	 99.9731% 	       29774
# Error Rate:      	 13.3333% 	        8 	  0.0269% 	           8
# Sub Rate:        	 13.3333% 	        8 	  0.0269% 	           8
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.825 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-02_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 8 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-03_2020.fasta out=../data_raw/UWHC/USA_WI-UW-03_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-03_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-03_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.025 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.705 seconds.
# Analyzed Index:   	3.009 seconds.
# Found samtools 1.9
# Started output stream:	0.089 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29870 bases)
#
# Mapping:          	0.281 seconds.
# Reads/sec:       	213.47
# kBases/sec:      	106.27
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29870
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29870
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 86.6667% 	       52 	 86.6086% 	       25870
# semiperfect site:	 86.6667% 	       52 	 86.6086% 	       25870
#
# Match Rate:      	      NA 	       NA 	 99.9732% 	       29862
# Error Rate:      	 13.3333% 	        8 	  0.0268% 	           8
# Sub Rate:        	 13.3333% 	        8 	  0.0268% 	           8
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.336 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-03_2020.fasta.pileup
# 29870 bases in pileup file
# 29870 met minimum coverage of 1x
# 8 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-04_2020.fasta out=../data_raw/UWHC/USA_WI-UW-04_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-04_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-04_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.038 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.995 seconds.
# Analyzed Index:   	4.703 seconds.
# Found samtools 1.9
# Started output stream:	0.091 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29843 bases)
#
# Mapping:          	0.475 seconds.
# Reads/sec:       	126.42
# kBases/sec:      	62.88
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29843
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29843
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2720% 	       26343
# semiperfect site:	 88.3333% 	       53 	 88.2720% 	       26343
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29836
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	6.601 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-04_2020.fasta.pileup
# 29843 bases in pileup file
# 29843 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-05_2020.fasta out=../data_raw/UWHC/USA_WI-UW-05_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-05_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-05_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.031 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.741 seconds.
# Analyzed Index:   	3.706 seconds.
# Found samtools 1.9
# Started output stream:	0.095 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29855 bases)
#
# Mapping:          	0.345 seconds.
# Reads/sec:       	173.79
# kBases/sec:      	86.48
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29855
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29855
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 86.6667% 	       52 	 87.0876% 	       26000
# semiperfect site:	 86.6667% 	       52 	 87.0876% 	       26000
#
# Match Rate:      	      NA 	       NA 	 99.9732% 	       29847
# Error Rate:      	 13.3333% 	        8 	  0.0268% 	           8
# Sub Rate:        	 13.3333% 	        8 	  0.0268% 	           8
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.186 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-05_2020.fasta.pileup
# 29855 bases in pileup file
# 29855 met minimum coverage of 1x
# 8 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-06_2020.fasta out=../data_raw/UWHC/USA_WI-UW-06_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-06_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-06_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.027 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.837 seconds.
# Analyzed Index:   	3.115 seconds.
# Found samtools 1.9
# Started output stream:	0.094 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29844 bases)
#
# Mapping:          	0.267 seconds.
# Reads/sec:       	224.84
# kBases/sec:      	111.84
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29844
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29844
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 85.0000% 	       51 	 85.4443% 	       25500
# semiperfect site:	 85.0000% 	       51 	 85.4443% 	       25500
#
# Match Rate:      	      NA 	       NA 	 99.9698% 	       29835
# Error Rate:      	 15.0000% 	        9 	  0.0302% 	           9
# Sub Rate:        	 15.0000% 	        9 	  0.0302% 	           9
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.586 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-06_2020.fasta.pileup
# 29844 bases in pileup file
# 29844 met minimum coverage of 1x
# 9 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-07_2020.fasta out=../data_raw/UWHC/USA_WI-UW-07_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-07_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-07_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.808 seconds.
# Analyzed Index:   	3.551 seconds.
# Found samtools 1.9
# Started output stream:	0.090 seconds.
# Cleared Memory:    	0.114 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29865 bases)
#
# Mapping:          	0.335 seconds.
# Reads/sec:       	178.84
# kBases/sec:      	89.02
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29865
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29865
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 83.3333% 	       50 	 83.7100% 	       25000
# semiperfect site:	 83.3333% 	       50 	 83.7100% 	       25000
#
# Match Rate:      	      NA 	       NA 	 99.9665% 	       29855
# Error Rate:      	 16.6667% 	       10 	  0.0335% 	          10
# Sub Rate:        	 16.6667% 	       10 	  0.0335% 	          10
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.042 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-07_2020.fasta.pileup
# 29865 bases in pileup file
# 29865 met minimum coverage of 1x
# 10 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-08_2020.fasta out=../data_raw/UWHC/USA_WI-UW-08_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-08_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-08_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.032 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.962 seconds.
# Analyzed Index:   	3.117 seconds.
# Found samtools 1.9
# Started output stream:	0.094 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29843 bases)
#
# Mapping:          	0.282 seconds.
# Reads/sec:       	212.90
# kBases/sec:      	105.89
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29843
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29843
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 90.4735% 	       27000
# semiperfect site:	 90.0000% 	       54 	 90.4735% 	       27000
#
# Match Rate:      	      NA 	       NA 	 99.9799% 	       29837
# Error Rate:      	 10.0000% 	        6 	  0.0201% 	           6
# Sub Rate:        	 10.0000% 	        6 	  0.0201% 	           6
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.754 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-08_2020.fasta.pileup
# 29843 bases in pileup file
# 29843 met minimum coverage of 1x
# 6 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-09_2020.fasta out=../data_raw/UWHC/USA_WI-UW-09_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-09_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-09_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.028 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	1.057 seconds.
# Analyzed Index:   	3.577 seconds.
# Found samtools 1.9
# Started output stream:	0.091 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29843 bases)
#
# Mapping:          	0.298 seconds.
# Reads/sec:       	201.42
# kBases/sec:      	100.18
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29843
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29843
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 91.6667% 	       55 	 91.6228% 	       27343
# semiperfect site:	 91.6667% 	       55 	 91.6228% 	       27343
#
# Match Rate:      	      NA 	       NA 	 99.9799% 	       29837
# Error Rate:      	  8.3333% 	        5 	  0.0201% 	           6
# Sub Rate:        	  8.3333% 	        5 	  0.0201% 	           6
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.306 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-09_2020.fasta.pileup
# 29843 bases in pileup file
# 29843 met minimum coverage of 1x
# 6 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-100_2020.fasta out=../data_raw/UWHC/USA_WI-UW-100_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-100_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-100_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.031 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.841 seconds.
# Analyzed Index:   	2.982 seconds.
# Found samtools 1.9
# Started output stream:	0.103 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.337 seconds.
# Reads/sec:       	177.81
# kBases/sec:      	88.26
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9731% 	       29774
# Error Rate:      	 10.0000% 	        6 	  0.0235% 	           7
# Sub Rate:        	 10.0000% 	        6 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.557 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-100_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-101_2020.fasta out=../data_raw/UWHC/USA_WI-UW-101_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-101_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-101_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.028 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.791 seconds.
# Analyzed Index:   	2.879 seconds.
# Found samtools 1.9
# Started output stream:	0.098 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.318 seconds.
# Reads/sec:       	188.81
# kBases/sec:      	93.72
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9731% 	       29774
# Error Rate:      	 11.6667% 	        7 	  0.0269% 	           8
# Sub Rate:        	 11.6667% 	        7 	  0.0269% 	           8
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.359 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-101_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 8 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-102_2020.fasta out=../data_raw/UWHC/USA_WI-UW-102_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-102_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-102_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.030 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.858 seconds.
# Analyzed Index:   	3.077 seconds.
# Found samtools 1.9
# Started output stream:	0.096 seconds.
# Cleared Memory:    	0.107 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.335 seconds.
# Reads/sec:       	179.33
# kBases/sec:      	89.01
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 83.3333% 	       50 	 83.2113% 	       24782
# semiperfect site:	 83.3333% 	       50 	 83.2113% 	       24782
#
# Match Rate:      	      NA 	       NA 	 99.9664% 	       29772
# Error Rate:      	 16.6667% 	       10 	  0.0336% 	          10
# Sub Rate:        	 16.6667% 	       10 	  0.0336% 	          10
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.642 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-102_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 10 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-103_2020.fasta out=../data_raw/UWHC/USA_WI-UW-103_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-103_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-103_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.035 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	1.065 seconds.
# Analyzed Index:   	3.054 seconds.
# Found samtools 1.9
# Started output stream:	0.111 seconds.
# Cleared Memory:    	0.115 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.329 seconds.
# Reads/sec:       	182.17
# kBases/sec:      	90.43
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 10.0000% 	        6 	  0.0235% 	           7
# Sub Rate:        	 10.0000% 	        6 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.879 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-103_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-105_2020.fasta out=../data_raw/UWHC/USA_WI-UW-105_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-105_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-105_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.033 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.907 seconds.
# Analyzed Index:   	3.802 seconds.
# Found samtools 1.9
# Started output stream:	0.148 seconds.
# Cleared Memory:    	0.117 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.332 seconds.
# Reads/sec:       	180.79
# kBases/sec:      	89.74
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.494 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-105_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-106_2020.fasta out=../data_raw/UWHC/USA_WI-UW-106_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-106_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-106_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.037 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.847 seconds.
# Analyzed Index:   	3.327 seconds.
# Found samtools 1.9
# Started output stream:	0.122 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.353 seconds.
# Reads/sec:       	169.97
# kBases/sec:      	84.37
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 91.6667% 	       55 	 91.6057% 	       27282
# semiperfect site:	 91.6667% 	       55 	 91.6057% 	       27282
#
# Match Rate:      	      NA 	       NA 	 99.9799% 	       29776
# Error Rate:      	  8.3333% 	        5 	  0.0201% 	           6
# Sub Rate:        	  8.3333% 	        5 	  0.0201% 	           6
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.032 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-106_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 6 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-107_2020.fasta out=../data_raw/UWHC/USA_WI-UW-107_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-107_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-107_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.920 seconds.
# Analyzed Index:   	4.591 seconds.
# Found samtools 1.9
# Started output stream:	0.141 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.404 seconds.
# Reads/sec:       	148.55
# kBases/sec:      	73.73
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 10.0000% 	        6 	  0.0235% 	           7
# Sub Rate:        	 10.0000% 	        6 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	6.330 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-107_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-108_2020.fasta out=../data_raw/UWHC/USA_WI-UW-108_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-108_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-108_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.032 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	1.621 seconds.
# Analyzed Index:   	5.279 seconds.
# Found samtools 1.9
# Started output stream:	0.200 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.436 seconds.
# Reads/sec:       	137.75
# kBases/sec:      	68.37
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 91.6667% 	       55 	 91.6057% 	       27282
# semiperfect site:	 91.6667% 	       55 	 91.6057% 	       27282
#
# Match Rate:      	      NA 	       NA 	 99.9832% 	       29777
# Error Rate:      	  8.3333% 	        5 	  0.0168% 	           5
# Sub Rate:        	  8.3333% 	        5 	  0.0168% 	           5
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	7.926 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-108_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 5 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-109_2020.fasta out=../data_raw/UWHC/USA_WI-UW-109_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-109_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-109_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.047 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	1.258 seconds.
# Analyzed Index:   	4.506 seconds.
# Found samtools 1.9
# Started output stream:	0.105 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.308 seconds.
# Reads/sec:       	195.10
# kBases/sec:      	96.84
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 91.6667% 	       55 	 91.6057% 	       27282
# semiperfect site:	 91.6667% 	       55 	 91.6057% 	       27282
#
# ...
# Cleared Memory:    	0.114 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.265 seconds.
# Reads/sec:       	226.75
# kBases/sec:      	112.55
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 10.0000% 	        6 	  0.0235% 	           7
# Sub Rate:        	 10.0000% 	        6 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.171 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-95_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-96_2020.fasta out=../data_raw/UWHC/USA_WI-UW-96_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-96_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-96_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.705 seconds.
# Analyzed Index:   	2.970 seconds.
# Found samtools 1.9
# Started output stream:	0.074 seconds.
# Cleared Memory:    	0.108 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.254 seconds.
# Reads/sec:       	235.91
# kBases/sec:      	117.10
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 80.0000% 	       48 	 80.5856% 	       24000
# semiperfect site:	 80.0000% 	       48 	 80.5856% 	       24000
#
# Match Rate:      	      NA 	       NA 	 99.9563% 	       29769
# Error Rate:      	 18.3333% 	       11 	  0.0403% 	          12
# Sub Rate:        	 18.3333% 	       11 	  0.0403% 	          12
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.253 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-96_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 12 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-97_2020.fasta out=../data_raw/UWHC/USA_WI-UW-97_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-97_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-97_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.716 seconds.
# Analyzed Index:   	2.999 seconds.
# Found samtools 1.9
# Started output stream:	0.077 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29611 bases)
#
# Mapping:          	0.252 seconds.
# Reads/sec:       	237.72
# kBases/sec:      	117.32
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29611
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29611
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.8686% 	       26611
# semiperfect site:	 90.0000% 	       54 	 89.8686% 	       26611
#
# Match Rate:      	      NA 	       NA 	 99.9764% 	       29604
# Error Rate:      	 10.0000% 	        6 	  0.0236% 	           7
# Sub Rate:        	 10.0000% 	        6 	  0.0236% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.297 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-97_2020.fasta.pileup
# 29611 bases in pileup file
# 29611 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-98_2020.fasta out=../data_raw/UWHC/USA_WI-UW-98_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-98_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-98_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.028 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.737 seconds.
# Analyzed Index:   	2.987 seconds.
# Found samtools 1.9
# Started output stream:	0.075 seconds.
# Cleared Memory:    	0.112 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.250 seconds.
# Reads/sec:       	240.14
# kBases/sec:      	119.20
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9799% 	       29776
# Error Rate:      	 10.0000% 	        6 	  0.0201% 	           6
# Sub Rate:        	 10.0000% 	        6 	  0.0201% 	           6
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.310 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-98_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 6 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI-UW-99_2020.fasta out=../data_raw/UWHC/USA_WI-UW-99_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI-UW-99_2020.fasta, out=../data_raw/UWHC/USA_WI-UW-99_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.694 seconds.
# Analyzed Index:   	3.730 seconds.
# Found samtools 1.9
# Started output stream:	0.128 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.315 seconds.
# Reads/sec:       	190.32
# kBases/sec:      	94.47
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.124 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI-UW-99_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/UWHC/USA_WI1_2020.fasta out=../data_raw/UWHC/USA_WI1_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/UWHC/USA_WI1_2020.fasta, out=../data_raw/UWHC/USA_WI1_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.743 seconds.
# Analyzed Index:   	3.215 seconds.
# Found samtools 1.9
# Started output stream:	0.076 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29879 bases)
#
# Mapping:          	0.447 seconds.
# Reads/sec:       	134.21
# kBases/sec:      	66.84
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29879
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29879
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 96.6532% 	       28879
# semiperfect site:	 96.6667% 	       58 	 96.6532% 	       28879
#
# Match Rate:      	      NA 	       NA 	 99.9866% 	       29878
# Error Rate:      	  3.3333% 	        2 	  0.0134% 	           4
# Sub Rate:        	  1.6667% 	        1 	  0.0033% 	           1
# Del Rate:        	  1.6667% 	        1 	  0.0100% 	           3
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.737 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/UWHC/USA_WI1_2020.fasta.pileup
# 29882 bases in pileup file
# 29882 met minimum coverage of 1x
# 1 SNPs predicted

# %%
# %%bash
#
# # MHD samples, this takes ~10 mins to run
#
# for file in $(ls ../data_raw/MHD/*.fasta)
# do
#     bbmap.sh in=$file out=$file.bam ref=ref.fa #map to Wuhan reference
#     samtools sort $file.bam -o $file.bam # sort the bam
#     samtools mpileup -f ref.fa $file.bam > $file.pileup # generate a pileup file
#     java -jar VarScan.jar pileup2snp $file.pileup --min-coverage 1 --min-reads2 1 > $file.vcf
# done
#
# ##
# Out:
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-156_2020.fasta out=../data_raw/MHD/USA_WI-UW-156_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-156_2020.fasta, out=../data_raw/MHD/USA_WI-UW-156_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.025 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.740 seconds.
# Analyzed Index:   	3.478 seconds.
# Found samtools 1.9
# Started output stream:	0.084 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.404 seconds.
# Reads/sec:       	148.35
# kBases/sec:      	73.64
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 86.6667% 	       52 	 86.5691% 	       25782
# semiperfect site:	 86.6667% 	       52 	 86.5691% 	       25782
#
# Match Rate:      	      NA 	       NA 	 99.9597% 	       29770
# Error Rate:      	 13.3333% 	        8 	  0.0403% 	          12
# Sub Rate:        	 13.3333% 	        8 	  0.0403% 	          12
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.968 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-156_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 12 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-157_2020.fasta out=../data_raw/MHD/USA_WI-UW-157_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-157_2020.fasta, out=../data_raw/MHD/USA_WI-UW-157_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.028 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.743 seconds.
# Analyzed Index:   	2.429 seconds.
# Found samtools 1.9
# Started output stream:	0.093 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.281 seconds.
# Reads/sec:       	213.78
# kBases/sec:      	106.11
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 98.3333% 	       59 	 99.0531% 	       29500
# semiperfect site:	 98.3333% 	       59 	 99.0531% 	       29500
#
# Match Rate:      	      NA 	       NA 	 99.9966% 	       29781
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	3.803 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-157_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-158_2020.fasta out=../data_raw/MHD/USA_WI-UW-158_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-158_2020.fasta, out=../data_raw/MHD/USA_WI-UW-158_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.731 seconds.
# Analyzed Index:   	2.454 seconds.
# Found samtools 1.9
# Started output stream:	0.086 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.264 seconds.
# Reads/sec:       	227.49
# kBases/sec:      	112.92
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9731% 	       29774
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	3.791 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-158_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-159_2020.fasta out=../data_raw/MHD/USA_WI-UW-159_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-159_2020.fasta, out=../data_raw/MHD/USA_WI-UW-159_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.716 seconds.
# Analyzed Index:   	3.014 seconds.
# Found samtools 1.9
# Started output stream:	0.083 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.216 seconds.
# Reads/sec:       	277.59
# kBases/sec:      	137.79
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 83.3333% 	       50 	 83.2113% 	       24782
# semiperfect site:	 83.3333% 	       50 	 83.2113% 	       24782
#
# Match Rate:      	      NA 	       NA 	 99.9664% 	       29772
# Error Rate:      	 15.0000% 	        9 	  0.0302% 	           9
# Sub Rate:        	 15.0000% 	        9 	  0.0302% 	           9
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.278 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-159_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 9 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-160_2020.fasta out=../data_raw/MHD/USA_WI-UW-160_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-160_2020.fasta, out=../data_raw/MHD/USA_WI-UW-160_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.732 seconds.
# Analyzed Index:   	2.504 seconds.
# Found samtools 1.9
# Started output stream:	0.089 seconds.
# Cleared Memory:    	0.114 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.260 seconds.
# Reads/sec:       	231.16
# kBases/sec:      	114.74
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	3.844 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-160_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-161_2020.fasta out=../data_raw/MHD/USA_WI-UW-161_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-161_2020.fasta, out=../data_raw/MHD/USA_WI-UW-161_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.737 seconds.
# Analyzed Index:   	3.029 seconds.
# Found samtools 1.9
# Started output stream:	0.083 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.293 seconds.
# Reads/sec:       	204.85
# kBases/sec:      	101.68
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 95.0000% 	       57 	 95.6954% 	       28500
# semiperfect site:	 95.0000% 	       57 	 95.6954% 	       28500
#
# Match Rate:      	      NA 	       NA 	 99.9899% 	       29779
# Error Rate:      	  5.0000% 	        3 	  0.0101% 	           3
# Sub Rate:        	  5.0000% 	        3 	  0.0101% 	           3
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.395 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-161_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 3 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-162_2020.fasta out=../data_raw/MHD/USA_WI-UW-162_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-162_2020.fasta, out=../data_raw/MHD/USA_WI-UW-162_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.025 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.703 seconds.
# Analyzed Index:   	3.042 seconds.
# Found samtools 1.9
# Started output stream:	0.077 seconds.
# Cleared Memory:    	0.112 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.310 seconds.
# Reads/sec:       	193.49
# kBases/sec:      	96.04
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# Error Rate:      	  3.3333% 	        2 	  0.0067% 	           2
# Sub Rate:        	  3.3333% 	        2 	  0.0067% 	           2
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.388 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-162_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 2 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-165_2020.fasta out=../data_raw/MHD/USA_WI-UW-165_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-165_2020.fasta, out=../data_raw/MHD/USA_WI-UW-165_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.030 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.725 seconds.
# Analyzed Index:   	3.181 seconds.
# Found samtools 1.9
# Started output stream:	0.095 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.283 seconds.
# Reads/sec:       	212.23
# kBases/sec:      	105.34
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 90.0000% 	       54 	 89.9268% 	       26782
# semiperfect site:	 90.0000% 	       54 	 89.9268% 	       26782
#
# Match Rate:      	      NA 	       NA 	 99.9799% 	       29776
# Error Rate:      	 10.0000% 	        6 	  0.0201% 	           6
# Sub Rate:        	 10.0000% 	        6 	  0.0201% 	           6
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.555 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-165_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 6 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-166_2020.fasta out=../data_raw/MHD/USA_WI-UW-166_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-166_2020.fasta, out=../data_raw/MHD/USA_WI-UW-166_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.029 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.727 seconds.
# Analyzed Index:   	3.029 seconds.
# Found samtools 1.9
# Started output stream:	0.084 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.234 seconds.
# Reads/sec:       	256.66
# kBases/sec:      	127.40
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 85.0000% 	       51 	 85.6222% 	       25500
# semiperfect site:	 85.0000% 	       51 	 85.6222% 	       25500
#
# Match Rate:      	      NA 	       NA 	 99.9664% 	       29772
# Error Rate:      	 15.0000% 	        9 	  0.0336% 	          10
# Sub Rate:        	 15.0000% 	        9 	  0.0336% 	          10
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.354 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-166_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 10 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-168_2020.fasta out=../data_raw/MHD/USA_WI-UW-168_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-168_2020.fasta, out=../data_raw/MHD/USA_WI-UW-168_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.035 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.859 seconds.
# Analyzed Index:   	3.278 seconds.
# Found samtools 1.9
# Started output stream:	0.098 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.315 seconds.
# Reads/sec:       	190.66
# kBases/sec:      	94.64
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 98.3333% 	       59 	 99.0531% 	       29500
# semiperfect site:	 98.3333% 	       59 	 99.0531% 	       29500
#
# Match Rate:      	      NA 	       NA 	 99.9966% 	       29781
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.967 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-168_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-170_2020.fasta out=../data_raw/MHD/USA_WI-UW-170_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-170_2020.fasta, out=../data_raw/MHD/USA_WI-UW-170_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.026 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.789 seconds.
# Analyzed Index:   	2.773 seconds.
# Found samtools 1.9
# Started output stream:	0.095 seconds.
# Cleared Memory:    	0.114 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.258 seconds.
# Reads/sec:       	232.78
# kBases/sec:      	115.54
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 98.3333% 	       59 	 99.0531% 	       29500
# semiperfect site:	 98.3333% 	       59 	 99.0531% 	       29500
#
# Match Rate:      	      NA 	       NA 	 99.9966% 	       29781
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.196 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-170_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-171_2020.fasta out=../data_raw/MHD/USA_WI-UW-171_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-171_2020.fasta, out=../data_raw/MHD/USA_WI-UW-171_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.031 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.775 seconds.
# Analyzed Index:   	3.401 seconds.
# Found samtools 1.9
# Started output stream:	0.091 seconds.
# Cleared Memory:    	0.108 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.283 seconds.
# Reads/sec:       	211.96
# kBases/sec:      	105.21
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.819 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-171_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-172_2020.fasta out=../data_raw/MHD/USA_WI-UW-172_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-172_2020.fasta, out=../data_raw/MHD/USA_WI-UW-172_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.693 seconds.
# Analyzed Index:   	2.532 seconds.
# Found samtools 1.9
# Started output stream:	0.094 seconds.
# Cleared Memory:    	0.112 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.232 seconds.
# Reads/sec:       	258.15
# kBases/sec:      	128.14
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# Error Rate:      	  3.3333% 	        2 	  0.0067% 	           2
# Sub Rate:        	  3.3333% 	        2 	  0.0067% 	           2
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	3.803 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-172_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 2 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-173_2020.fasta out=../data_raw/MHD/USA_WI-UW-173_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-173_2020.fasta, out=../data_raw/MHD/USA_WI-UW-173_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.721 seconds.
# Analyzed Index:   	3.333 seconds.
# Found samtools 1.9
# Started output stream:	0.168 seconds.
# Cleared Memory:    	0.133 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.262 seconds.
# Reads/sec:       	228.95
# kBases/sec:      	113.64
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 98.3333% 	       59 	 99.0531% 	       29500
# semiperfect site:	 98.3333% 	       59 	 99.0531% 	       29500
#
# Match Rate:      	      NA 	       NA 	 99.9966% 	       29781
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.772 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-173_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-176_2020.fasta out=../data_raw/MHD/USA_WI-UW-176_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-176_2020.fasta, out=../data_raw/MHD/USA_WI-UW-176_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.891 seconds.
# Analyzed Index:   	2.585 seconds.
# Found samtools 1.9
# Started output stream:	0.080 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.254 seconds.
# Reads/sec:       	236.22
# kBases/sec:      	117.25
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.2479% 	       26282
# semiperfect site:	 88.3333% 	       53 	 88.2479% 	       26282
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.069 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-176_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-177_2020.fasta out=../data_raw/MHD/USA_WI-UW-177_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-177_2020.fasta, out=../data_raw/MHD/USA_WI-UW-177_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.729 seconds.
# Analyzed Index:   	3.008 seconds.
# Found samtools 1.9
# Started output stream:	0.086 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.254 seconds.
# Reads/sec:       	236.48
# kBases/sec:      	117.38
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# Error Rate:      	  3.3333% 	        2 	  0.0067% 	           2
# Sub Rate:        	  3.3333% 	        2 	  0.0067% 	           2
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.326 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-177_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 2 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-178_2020.fasta out=../data_raw/MHD/USA_WI-UW-178_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-178_2020.fasta, out=../data_raw/MHD/USA_WI-UW-178_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.713 seconds.
# Analyzed Index:   	2.750 seconds.
# Found samtools 1.9
# Started output stream:	0.083 seconds.
# Cleared Memory:    	0.113 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.251 seconds.
# Reads/sec:       	239.16
# kBases/sec:      	118.71
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# ...
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.304 seconds.
# Reads/sec:       	197.15
# kBases/sec:      	97.86
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 86.6667% 	       52 	 86.5691% 	       25782
# semiperfect site:	 86.6667% 	       52 	 86.5691% 	       25782
#
# Match Rate:      	      NA 	       NA 	 99.9731% 	       29774
# Error Rate:      	 13.3333% 	        8 	  0.0269% 	           8
# Sub Rate:        	 13.3333% 	        8 	  0.0269% 	           8
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	5.547 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-341_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 8 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-342_2020.fasta out=../data_raw/MHD/USA_WI-UW-342_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-342_2020.fasta, out=../data_raw/MHD/USA_WI-UW-342_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.069 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.931 seconds.
# Analyzed Index:   	3.026 seconds.
# Found samtools 1.9
# Started output stream:	0.077 seconds.
# Cleared Memory:    	0.109 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.278 seconds.
# Reads/sec:       	215.87
# kBases/sec:      	107.15
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 98.3333% 	       59 	 99.0531% 	       29500
# semiperfect site:	 98.3333% 	       59 	 99.0531% 	       29500
#
# Match Rate:      	      NA 	       NA 	 99.9966% 	       29781
# Error Rate:      	  1.6667% 	        1 	  0.0034% 	           1
# Sub Rate:        	  1.6667% 	        1 	  0.0034% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.714 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-342_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-343_2020.fasta out=../data_raw/MHD/USA_WI-UW-343_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-343_2020.fasta, out=../data_raw/MHD/USA_WI-UW-343_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.027 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.754 seconds.
# Analyzed Index:   	3.028 seconds.
# Found samtools 1.9
# Started output stream:	0.087 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.243 seconds.
# Reads/sec:       	246.74
# kBases/sec:      	122.47
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 95.0000% 	       57 	 95.6954% 	       28500
# semiperfect site:	 95.0000% 	       57 	 95.6954% 	       28500
#
# Match Rate:      	      NA 	       NA 	 99.9899% 	       29779
# Error Rate:      	  3.3333% 	        2 	  0.0067% 	           2
# Sub Rate:        	  3.3333% 	        2 	  0.0067% 	           2
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  1.6667% 	        1 	  0.0034% 	           1
#
# Total time:     	4.366 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-343_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 2 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-344_2020.fasta out=../data_raw/MHD/USA_WI-UW-344_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-344_2020.fasta, out=../data_raw/MHD/USA_WI-UW-344_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.024 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.711 seconds.
# Analyzed Index:   	3.092 seconds.
# Found samtools 1.9
# Started output stream:	0.091 seconds.
# Cleared Memory:    	0.112 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.239 seconds.
# Reads/sec:       	251.05
# kBases/sec:      	124.61
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 88.3333% 	       53 	 88.9799% 	       26500
# semiperfect site:	 88.3333% 	       53 	 88.9799% 	       26500
#
# Match Rate:      	      NA 	       NA 	 99.9765% 	       29775
# Error Rate:      	 11.6667% 	        7 	  0.0235% 	           7
# Sub Rate:        	 11.6667% 	        7 	  0.0235% 	           7
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.382 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-344_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 7 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-345_2020.fasta out=../data_raw/MHD/USA_WI-UW-345_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-345_2020.fasta, out=../data_raw/MHD/USA_WI-UW-345_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.788 seconds.
# Analyzed Index:   	2.782 seconds.
# Found samtools 1.9
# Started output stream:	0.087 seconds.
# Cleared Memory:    	0.111 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29611 bases)
#
# Mapping:          	0.262 seconds.
# Reads/sec:       	229.40
# kBases/sec:      	113.21
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	 96.6667% 	       58 	 96.6229% 	       28611
# unambiguous:     	 96.6667% 	       58 	 96.6229% 	       28611
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  3.3333% 	        2 	  3.3771% 	        1000
#
# perfect best site:	 85.0000% 	       51 	 84.8029% 	       25111
# semiperfect site:	 85.0000% 	       51 	 84.8029% 	       25111
#
# Match Rate:      	      NA 	       NA 	 98.1755% 	       28089
# Error Rate:      	  1.7241% 	        1 	  0.0035% 	           1
# Sub Rate:        	  1.7241% 	        1 	  0.0035% 	           1
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	 10.3448% 	        6 	  1.8210% 	         521
#
# Total time:     	4.165 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-345_2020.fasta.pileup
# 28611 bases in pileup file
# 28611 met minimum coverage of 1x
# 1 SNPs predicted
# Max memory cannot be determined.  Attempting to use 3200 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -Djava.library.path=/Users/katbraun/anaconda3/opt/bbmap-38.22-1/jni/ -ea -Xmx3200m -cp /Users/katbraun/anaconda3/opt/bbmap-38.22-1/current/ align2.BBMap build=1 overwrite=true fastareadlen=500 in=../data_raw/MHD/USA_WI-UW-346_2020.fasta out=../data_raw/MHD/USA_WI-UW-346_2020.fasta.bam ref=ref.fa
# Executing align2.BBMap [build=1, overwrite=true, fastareadlen=500, in=../data_raw/MHD/USA_WI-UW-346_2020.fasta, out=../data_raw/MHD/USA_WI-UW-346_2020.fasta.bam, ref=ref.fa]
# Version 38.22
#
# Retaining first best site only for ambiguous mappings.
# NOTE:	Ignoring reference file because it already appears to have been processed.
# NOTE:	If you wish to regenerate the index, please manually delete ref/genome/1/summary.txt
# Set genome to 1
#
# Loaded Reference:	0.023 seconds.
# Loading index for chunk 1-1, build 1
# Generated Index:	0.747 seconds.
# Analyzed Index:   	2.984 seconds.
# Found samtools 1.9
# Started output stream:	0.083 seconds.
# Cleared Memory:    	0.110 seconds.
# Processing reads in single-ended mode.
# Started read stream.
# Started 4 mapping threads.
# Detecting finished threads: 0, 1, 2, 3
#
#    ------------------   Results   ------------------
#
# Genome:                	1
# Key Length:            	13
# Max Indel:             	16000
# Minimum Score Ratio:  	0.56
# Mapping Mode:         	normal
# Reads Used:           	60	(29782 bases)
#
# Mapping:          	0.262 seconds.
# Reads/sec:       	228.93
# kBases/sec:      	113.63
#
#
# Read 1 data:      	pct reads	num reads 	pct bases	   num bases
#
# mapped:          	100.0000% 	       60 	100.0000% 	       29782
# unambiguous:     	100.0000% 	       60 	100.0000% 	       29782
# ambiguous:       	  0.0000% 	        0 	  0.0000% 	           0
# low-Q discards:  	  0.0000% 	        0 	  0.0000% 	           0
#
# perfect best site:	 96.6667% 	       58 	 97.3743% 	       29000
# semiperfect site:	 96.6667% 	       58 	 97.3743% 	       29000
#
# Match Rate:      	      NA 	       NA 	 99.9933% 	       29780
# Error Rate:      	  3.3333% 	        2 	  0.0067% 	           2
# Sub Rate:        	  3.3333% 	        2 	  0.0067% 	           2
# Del Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# Ins Rate:        	  0.0000% 	        0 	  0.0000% 	           0
# N Rate:          	  0.0000% 	        0 	  0.0000% 	           0
#
# Total time:     	4.326 seconds.
# [mpileup] 1 samples in 1 input files
# Warning: No p-value threshold provided, so p-values will not be calculated
# Min coverage:	1
# Min reads2:	1
# Min var freq:	0.01
# Min avg qual:	15
# P-value thresh:	0.99
# Reading input from ../data_raw/MHD/USA_WI-UW-346_2020.fasta.pileup
# 29782 bases in pileup file
# 29782 met minimum coverage of 1x
# 2 SNPs predicted

# %%
# move *.vcf files from data_raw to data_derived 
# UWHC

root_path = "../data_raw/Dane/"
dest_path = "../data_derived/Dane/VCFs/"

for dirpath, dnames, fnames in os.walk(root_path):    
    for f in fnames:
        if f.endswith(".vcf"):
            source_file_path =  os.path.join(dirpath, f)
            dest_file_path   =  os.path.join(dest_path, f)
            sh.copyfile(source_file_path, dest_file_path)

# %%
# move *.vcf files from data_raw to data_derived 
# MHD

root_path = "../data_raw/MKE/"
dest_path = "../data_derived/MKE/VCFs/"

for dirpath, dnames, fnames in os.walk(root_path):    
    for f in fnames:
        if f.endswith(".vcf"):
            source_file_path =  os.path.join(dirpath, f)
            dest_file_path   =  os.path.join(dest_path, f)
            sh.copyfile(source_file_path, dest_file_path)

# %% [markdown]
# ## cleanup data_raw directories
#
# Get rid of *bam* and *pileup* files generated above.

# %%
# UWHC cleanup 

dir_name = "../data_raw/Dane/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".bam"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".pileup"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".vcf"):
        os.remove(os.path.join(dir_name, item))

# %%
# MHD cleanup 

dir_name = "../data_raw/MKE/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".bam"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".pileup"):
        os.remove(os.path.join(dir_name, item))
        
for item in test:
    if item.endswith(".vcf"):
        os.remove(os.path.join(dir_name, item))

# %% [markdown]
# ## load VCF files into dataframes

# %%
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf')]
    list_of_DFs = []
    for file in filelist: 
#         print(file)
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False)
        file['sample'] = DF
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

# %%
# there are two MDH samples (270 and 339) that don't have any consensus SNVs -- these are identical to Wuhan/1
# I am going to write a NaN-only line into the VCFs so the cleaning functions to spit out errors 

with open('../data_derived/MKE/VCFs/USA_WI-UW-270_2020.fasta.vcf', 'a') as file:
    file.write('NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN')
    
with open('../data_derived/MKE/VCFs/USA_WI-UW-339_2020.fasta.vcf', 'a') as file:
    file.write('NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN')

# %%
# generate a list of dataframes

list_of_Dane_DFs = load_dataframes('../data_derived/Dane/VCFs')

list_of_MKE_DFs = load_dataframes('../data_derived/MKE/VCFs')
# Out:
# ['USA_WI-UW-356_2020.fasta', 'USA_WI-UW-28_2020.fasta', 'USA_WI-UW-59_2020.fasta', 'USA_WI-UW-44_2020.fasta', 'USA_WI-UW-51_2020.fasta', 'USA_WI-UW-35_2020.fasta', 'USA_WI-UW-116_2020.fasta', 'USA_WI-UW-103_2020.fasta', 'USA_WI-UW-351_2020.fasta', 'USA_WI-UW-119_2020.fasta', 'USA_WI-UW-56_2020.fasta', 'USA_WI-UW-43_2020.fasta', 'USA_WI-UW-359_2020.fasta', 'USA_WI-UW-111_2020.fasta', 'USA_WI-UW-32_2020.fasta', 'USA_WI-UW-27_2020.fasta', 'USA_WI-UW-42_2020.fasta', 'USA_WI-UW-26_2020.fasta', 'USA_WI-UW-33_2020.fasta', 'USA_WI-UW-110_2020.fasta', 'USA_WI-UW-105_2020.fasta', 'USA_WI-UW-50_2020.fasta', 'USA_WI-UW-45_2020.fasta', 'USA_WI-UW-102_2020.fasta', 'USA_WI-UW-117_2020.fasta', 'USA_WI-UW-34_2020.fasta', 'USA_WI-UW-29_2020.fasta', 'USA_WI-UW-58_2020.fasta', 'USA_WI-UW-100_2020.fasta', 'USA_WI-UW-115_2020.fasta', 'USA_WI-UW-52_2020.fasta', 'USA_WI-UW-108_2020.fasta', 'USA_WI-UW-112_2020.fasta', 'USA_WI-UW-107_2020.fasta', 'USA_WI-UW-259_2020.fasta', 'USA_WI-UW-31_2020.fasta', 'USA_WI-UW-40_2020.fasta', 'USA_WI-UW-55_2020.fasta', 'USA_WI-UW-48_2020.fasta', 'USA_WI-UW-39_2020.fasta', 'USA_WI-UW-347_2020.fasta', 'USA_WI-UW-49_2020.fasta', 'USA_WI-UW-38_2020.fasta', 'USA_WI-UW-25_2020.fasta', 'USA_WI-UW-106_2020.fasta', 'USA_WI-UW-54_2020.fasta', 'USA_WI-UW-41_2020.fasta', 'USA_WI-UW-109_2020.fasta', 'USA_WI-UW-114_2020.fasta', 'USA_WI-UW-101_2020.fasta', 'USA_WI-UW-37_2020.fasta', 'USA_WI-UW-46_2020.fasta', 'USA_WI-UW-53_2020.fasta', 'USA_WI-UW-85_2020.fasta', 'USA_WI-UW-90_2020.fasta', 'USA_WI-UW-128_2020.fasta', 'USA_WI-UW-03_2020.fasta', 'USA_WI-UW-120_2020.fasta', 'USA_WI-UW-135_2020.fasta', 'USA_WI-UW-98_2020.fasta', 'USA_WI-UW-72_2020.fasta', 'USA_WI-UW-67_2020.fasta', 'USA_WI-UW-144_2020.fasta', 'USA_WI-UW-151_2020.fasta', 'USA_WI-UW-68_2020.fasta', 'USA_WI-UW-97_2020.fasta', 'USA_WI-UW-82_2020.fasta', 'USA_WI-UW-127_2020.fasta', 'USA_WI-UW-04_2020.fasta', 'USA_WI-UW-60_2020.fasta', 'USA_WI-UW-75_2020.fasta', 'USA_WI-UW-10_2020.fasta', 'USA_WI-UW-05_2020.fasta', 'USA_WI-UW-74_2020.fasta', 'USA_WI-UW-61_2020.fasta', 'USA_WI-UW-69_2020.fasta', 'USA_WI-UW-96_2020.fasta', 'USA_WI-UW-99_2020.fasta', 'USA_WI-UW-02_2020.fasta', 'USA_WI-UW-150_2020.fasta', 'USA_WI-UW-145_2020.fasta', 'USA_WI-UW-66_2020.fasta', 'USA_WI-UW-73_2020.fasta', 'USA_WI-UW-129_2020.fasta', 'USA_WI-UW-91_2020.fasta', 'USA_WI-UW-84_2020.fasta', 'USA_WI-UW-64_2020.fasta', 'USA_WI-UW-71_2020.fasta', 'USA_WI-UW-152_2020.fasta', 'USA_WI-UW-147_2020.fasta', 'USA_WI-UW-93_2020.fasta', 'USA_WI-UW-86_2020.fasta', 'USA_WI-UW-08_2020.fasta', 'USA_WI-UW-260_2020.fasta', 'USA_WI-UW-79_2020.fasta', 'USA_WI-UW-140_2020.fasta', 'USA_WI-UW-155_2020.fasta', 'USA_WI-UW-76_2020.fasta', 'USA_WI-UW-63_2020.fasta', 'USA_WI-UW-89_2020.fasta', 'USA_WI-UW-124_2020.fasta', 'USA_WI-UW-07_2020.fasta', 'USA_WI-UW-81_2020.fasta', 'USA_WI-UW-94_2020.fasta', 'USA_WI-UW-148_2020.fasta', 'USA_WI-UW-95_2020.fasta', 'USA_WI-UW-80_2020.fasta', 'USA_WI-UW-62_2020.fasta', 'USA_WI-UW-77_2020.fasta', 'USA_WI-UW-06_2020.fasta', 'USA_WI1_2020.fasta', 'USA_WI-UW-88_2020.fasta', 'USA_WI-UW-09_2020.fasta', 'USA_WI-UW-362_2020.fasta', 'USA_WI-UW-87_2020.fasta', 'USA_WI-UW-92_2020.fasta', 'USA_WI-UW-78_2020.fasta', 'USA_WI-UW-146_2020.fasta', 'USA_WI-UW-153_2020.fasta', 'USA_WI-UW-70_2020.fasta', 'USA_WI-UW-65_2020.fasta', 'USA_WI-UW-122_2020.fasta']
# ['USA_WI-UW-343_2020.fasta', 'USA_WI-UW-240_2020.fasta', 'USA_WI-UW-185_2020.fasta', 'USA_WI-UW-190_2020.fasta', 'USA_WI-UW-332_2020.fasta', 'USA_WI-UW-231_2020.fasta', 'USA_WI-UW-172_2020.fasta', 'USA_WI-UW-248_2020.fasta', 'USA_WI-UW-197_2020.fasta', 'USA_WI-UW-182_2020.fasta', 'USA_WI-UW-344_2020.fasta', 'USA_WI-UW-223_2020.fasta', 'USA_WI-UW-236_2020.fasta', 'USA_WI-UW-168_2020.fasta', 'USA_WI-UW-335_2020.fasta', 'USA_WI-UW-320_2020.fasta', 'USA_WI-UW-160_2020.fasta', 'USA_WI-UW-328_2020.fasta', 'USA_WI-UW-161_2020.fasta', 'USA_WI-UW-329_2020.fasta', 'USA_WI-UW-345_2020.fasta', 'USA_WI-UW-246_2020.fasta', 'USA_WI-UW-183_2020.fasta', 'USA_WI-UW-196_2020.fasta', 'USA_WI-UW-321_2020.fasta', 'USA_WI-UW-334_2020.fasta', 'USA_WI-UW-237_2020.fasta', 'USA_WI-UW-222_2020.fasta', 'USA_WI-UW-166_2020.fasta', 'USA_WI-UW-173_2020.fasta', 'USA_WI-UW-238_2020.fasta', 'USA_WI-UW-191_2020.fasta', 'USA_WI-UW-184_2020.fasta', 'USA_WI-UW-241_2020.fasta', 'USA_WI-UW-342_2020.fasta', 'USA_WI-UW-225_2020.fasta', 'USA_WI-UW-230_2020.fasta', 'USA_WI-UW-333_2020.fasta', 'USA_WI-UW-171_2020.fasta', 'USA_WI-UW-339_2020.fasta', 'USA_WI-UW-179_2020.fasta', 'USA_WI-UW-331_2020.fasta', 'USA_WI-UW-324_2020.fasta', 'USA_WI-UW-227_2020.fasta', 'USA_WI-UW-232_2020.fasta', 'USA_WI-UW-340_2020.fasta', 'USA_WI-UW-186_2020.fasta', 'USA_WI-UW-189_2020.fasta', 'USA_WI-UW-176_2020.fasta', 'USA_WI-UW-228_2020.fasta', 'USA_WI-UW-235_2020.fasta', 'USA_WI-UW-323_2020.fasta', 'USA_WI-UW-336_2020.fasta', 'USA_WI-UW-181_2020.fasta', 'USA_WI-UW-337_2020.fasta', 'USA_WI-UW-322_2020.fasta', 'USA_WI-UW-221_2020.fasta', 'USA_WI-UW-234_2020.fasta', 'USA_WI-UW-346_2020.fasta', 'USA_WI-UW-245_2020.fasta', 'USA_WI-UW-195_2020.fasta', 'USA_WI-UW-188_2020.fasta', 'USA_WI-UW-229_2020.fasta', 'USA_WI-UW-162_2020.fasta', 'USA_WI-UW-177_2020.fasta', 'USA_WI-UW-233_2020.fasta', 'USA_WI-UW-226_2020.fasta', 'USA_WI-UW-178_2020.fasta', 'USA_WI-UW-325_2020.fasta', 'USA_WI-UW-330_2020.fasta', 'USA_WI-UW-187_2020.fasta', 'USA_WI-UW-192_2020.fasta', 'USA_WI-UW-242_2020.fasta', 'USA_WI-UW-341_2020.fasta', 'USA_WI-UW-170_2020.fasta', 'USA_WI-UW-165_2020.fasta', 'USA_WI-UW-338_2020.fasta', 'USA_WI-UW-289_2020.fasta', 'USA_WI-UW-159_2020.fasta', 'USA_WI-UW-304_2020.fasta', 'USA_WI-UW-207_2020.fasta', 'USA_WI-UW-212_2020.fasta', 'USA_WI-UW-276_2020.fasta', 'USA_WI-UW-319_2020.fasta', 'USA_WI-UW-215_2020.fasta', 'USA_WI-UW-200_2020.fasta', 'USA_WI-UW-303_2020.fasta', 'USA_WI-UW-316_2020.fasta', 'USA_WI-UW-279_2020.fasta', 'USA_WI-UW-293_2020.fasta', 'USA_WI-UW-156_2020.fasta', 'USA_WI-UW-208_2020.fasta', 'USA_WI-UW-278_2020.fasta', 'USA_WI-UW-209_2020.fasta', 'USA_WI-UW-157_2020.fasta', 'USA_WI-UW-302_2020.fasta', 'USA_WI-UW-270_2020.fasta', 'USA_WI-UW-280_2020.fasta', 'USA_WI-UW-213_2020.fasta', 'USA_WI-UW-158_2020.fasta', 'USA_WI-UW-305_2020.fasta', 'USA_WI-UW-310_2020.fasta', 'USA_WI-UW-288_2020.fasta', 'USA_WI-UW-277_2020.fasta', 'USA_WI-UW-219_2020.fasta', 'USA_WI-UW-275_2020.fasta', 'USA_WI-UW-211_2020.fasta', 'USA_WI-UW-290_2020.fasta', 'USA_WI-UW-285_2020.fasta', 'USA_WI-UW-308_2020.fasta', 'USA_WI-UW-272_2020.fasta', 'USA_WI-UW-216_2020.fasta', 'USA_WI-UW-273_2020.fasta', 'USA_WI-UW-299_2020.fasta', 'USA_WI-UW-301_2020.fasta', 'USA_WI-UW-217_2020.fasta', 'USA_WI-UW-309_2020.fasta', 'USA_WI-UW-291_2020.fasta', 'USA_WI-UW-274_2020.fasta', 'USA_WI-UW-205_2020.fasta', 'USA_WI-UW-210_2020.fasta', 'USA_WI-UW-313_2020.fasta', 'USA_WI-UW-306_2020.fasta', 'USA_WI-UW-296_2020.fasta', 'USA_WI-UW-218_2020.fasta']

# %%
# clean up the VCF files and save as CSV files 

def clean_Dane_dataframes(path, list_of_DFs):
    if not os.path.exists(path + '/cleaned'):
            os.makedirs(path + '/cleaned')
    for DF in list_of_DFs:
        DF = DF[['sample', 'Position', 'Ref', 'Cons']]
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('../data_derived/Dane/VCFs/'))
        DF['sample'] = DF['sample'].map(lambda x: x.rstrip('.fasta.vcf'))
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('SA_'))
        sample = DF['sample'].values[0]
        DF.to_csv(path + 'cleaned/' + sample + '-cleaned.csv', sep='\t')
        
def clean_MKE_dataframes(path, list_of_DFs):
    if not os.path.exists(path + '/cleaned'):
            os.makedirs(path + '/cleaned')
    for DF in list_of_DFs:
        DF = DF[['sample', 'Position', 'Ref', 'Cons']]
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('../data_derived/MKE/VCFs/'))
        DF['sample'] = DF['sample'].map(lambda x: x.rstrip('.fasta.vcf'))
        DF['sample'] = DF['sample'].map(lambda x: x.lstrip('USA_'))
        sample = DF['sample'].values[0]
        DF.to_csv(path + 'cleaned/' + sample + '-cleaned.csv', sep='\t')

# %%
# clean up all of the dataframes and save to new CSV files 

clean_Dane_dataframes('../data_derived/Dane/', list_of_Dane_DFs) # Dane County

clean_MKE_dataframes('../data_derived/MKE/', list_of_MKE_DFs) # Milwaukee County
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# check to make sure there is the correct number of cleaned CSV files in each cleaned directory 

path, dirs, files = next(os.walk("../data_derived/Dane/cleaned"))
Dane_len = len(files)

path, dirs, files = next(os.walk("../data_derived/MKE/cleaned"))
MKE_len = len(files)

print(Dane_len) # should be 122
print(MKE_len) # should be 125
# Out:
# 122
# 125

# %%
# merge all SNVs into a single dataframe

Dane_all = pd.concat([pd.read_csv(f, sep='\t') for f in glob.glob("../data_derived/Dane/cleaned/*.csv")], ignore_index=True)
Dane_all = Dane_all[['sample', 'Position']]

MKE_all = pd.concat([pd.read_csv(f, sep='\t') for f in glob.glob("../data_derived/MKE/cleaned/*.csv")], ignore_index=True)
MKE_all = MKE_all[['sample', 'Position']]
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
MKEannots = pd.concat([pd.read_csv(f, sep='\t') for f in glob.glob("../data_derived/MKE/cleaned/*.csv")], ignore_index=True)

MKEannots = MKEannots.drop_duplicates(subset='Position', keep="first")

MKEannots = MKEannots[['Cons', 'Position', 'Ref', 'sample']]

MKEannots.to_csv("/Users/katbraun/Desktop/MKEannots.csv")
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
# print the total number of SNVs as well as the total number of unique SNVs in each catchment area 

Dane_unique = Dane_all.drop_duplicates(subset='Position', keep="first")
MKE_unique = MKE_all.drop_duplicates(subset='Position', keep="first")

print("Total # of Dane SNVs:", len(Dane_all)) # total number of UWHC SNVs 
print("Total # of MKE SNVs:", len(MKE_all)) # total number of MHD SNVs

print("# of unique Dane SNVs:", len(Dane_unique)) # total number of UWHC SNVs 
print("# of unique MKE SNVs:", len(MKE_unique)) # total number of MHD SNVs

#
# Out:
# Total # of Dane SNVs: 933
# Total # of MKE SNVs: 627
# # of unique Dane SNVs: 155
# # of unique MKE SNVs: 148

# %% [markdown]
# ## load metadata

# %%
metadata = pd.read_csv('../data_raw/metadata.csv')

metadata = metadata[['Position', 'Annotations']]

metadata_dict = dict(zip(metadata.Position, metadata.Annotations))

# %%
temp = Dane_all.groupby('Position')['sample'].apply(','.join)

Dane_group = pd.DataFrame(temp)

Dane_group = Dane_group['sample'].str.split(pat=",", expand=True)

Dane_group['Sample_count'] = Dane_group.apply(lambda x: x.count(), axis=1)

Dane_group = Dane_group[['Sample_count']]

Dane_group = Dane_group.reset_index()

Dane_group['Annotation']= Dane_group['Position'].map(metadata_dict)

# Dane_group

#

# %%
temp1 = MKE_all.groupby('Position')['sample'].apply(','.join)

MKE_group = pd.DataFrame(temp1)

MKE_group = MKE_group['sample'].str.split(pat=",", expand=True)

MKE_group['Sample_count'] = MKE_group.apply(lambda x: x.count(), axis=1)

MKE_group = MKE_group[['Sample_count']]

MKE_group = MKE_group.reset_index()

MKE_group['Annotation']= MKE_group['Position'].map(metadata_dict)

#

# %%
# split dataframe into synonymous + intergenic (open datapoints)

Dane_group_syn_temp = Dane_group.loc[Dane_group.Annotation=='synonymous']

Dane_group_intergenic = Dane_group.loc[Dane_group.Annotation=='intergenic']

Dane_frames_syn = [Dane_group_syn_temp, Dane_group_intergenic]

Dane_group_syn = pd.concat(Dane_frames_syn)

Dane_group_syn = Dane_group_syn.sort_values('Position')

# split dataframe into nonsynonymous (closed datapoints)

Dane_group_nonsyn = Dane_group.loc[Dane_group.Annotation=='nonsynonymous']

Dane_group_nonsyn = Dane_group_nonsyn.sort_values('Position')

#

# %%
# split dataframe into synonymous + intergenic (open datapoints)

MKE_group_syn_temp = MKE_group.loc[MKE_group.Annotation=='synonymous']

MKE_group_intergenic = MKE_group.loc[MKE_group.Annotation=='intergenic']

MKE_frames_syn = [MKE_group_syn_temp, MKE_group_intergenic]

MKE_group_syn = pd.concat(MKE_frames_syn)

MKE_group_syn = MKE_group_syn.sort_values('Position')

# split dataframe into nonsynonymous (closed datapoints)

MKE_group_nonsyn = MKE_group.loc[MKE_group.Annotation=='nonsynonymous']

MKE_group_nonsyn = MKE_group_nonsyn.sort_values('Position')


#

# %%
Dane_syn = len(Dane_group_syn)
Dane_nonsyn = len(Dane_group_nonsyn)

MKE_syn = len(MKE_group_syn)
MKE_nonsyn = len(MKE_group_nonsyn)

Dane_ratio = Dane_nonsyn / Dane_syn
MKE_ratio = MKE_nonsyn / MKE_syn

print("# of synonymous SNVs in Dane county is ", len(Dane_group_syn))
print("# of nonsynonymous SNVs in Dane county is ", len(Dane_group_nonsyn))

print("# of synonymous SNVs in MKE county is ", len(MKE_group_syn))
print("# of nonsynonymous SNVs in MKE county is ", len(MKE_group_nonsyn))

print("ratio of nonsyn/syn in Dane county is ", Dane_ratio)
print("ratio of nonsyn/syn in MKE county is ", MKE_ratio)
# Out:
# # of synonymous SNVs in Dane county is  73
# # of nonsynonymous SNVs in Dane county is  82
# # of synonymous SNVs in MKE county is  53
# # of nonsynonymous SNVs in MKE county is  94
# ratio of nonsyn/syn in Dane county is  1.1232876712328768
# ratio of nonsyn/syn in MKE county is  1.7735849056603774

# %%
#SNV Count and Mean Inter-patient pairwise difference

temp3 = Dane_all.groupby('sample').Position.apply(lambda x: ','.join(map(str, x)))

Dane_group = pd.DataFrame(temp3)

Dane_group['SNV_count'] = Dane_group.Position.str.count(',') + 1

Dane_group = Dane_group[['SNV_count']]

temp4 = MKE_all.groupby('sample').Position.apply(lambda x: ','.join(map(str, x)))

MKE_group = pd.DataFrame(temp4)

MKE_group['SNV_count'] = MKE_group.Position.str.count(',') + 1

MKE_group = MKE_group[['SNV_count']]

print("average interpatient SNV distance for MKE is ", MKE_group['SNV_count'].mean())
print("std interpatient SNV distance for MKE is ", MKE_group['SNV_count'].std())

print("average interpatient SNV distance for Dane is ", Dane_group['SNV_count'].mean())
print("std interpatient SNV distance for Dane is ", Dane_group['SNV_count'].std())

#
# Out:
# average interpatient SNV distance for MKE is  5.016
# std interpatient SNV distance for MKE is  3.630035990224146
# average interpatient SNV distance for Dane is  7.647540983606557
# std interpatient SNV distance for Dane is  1.826897886236725

# %% [markdown]
# # generate the SNV figure

# %%
# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(12,8), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(4, 12)

ax1 = fig.add_subplot(gs[1,0:6])
ax2 = fig.add_subplot(gs[2,0:6])

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(True)
ax2.spines['left'].set_visible(True)

# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

ax2.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax2.tick_params(axis = 'both', which = 'minor', labelsize = 10)

ax1.set_xlabel('', fontname='Arial', fontsize=10)
ax1.set_ylabel('# of sequences', fontname='Arial', fontsize=10)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-2,102)
ax1.set_xlim(-2,30000)
ax1.set_xticks([0, 5000, 10000, 15000, 20000, 25000, 30000])

ax2.set_xlabel('\n genome position', fontname='Arial', fontsize=10)
ax2.set_ylabel('# of sequences', fontname='Arial', fontsize=10)
ax2.set_facecolor('white')
for tick in ax2.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax2.get_yticklabels():
    tick.set_fontname("Arial")
ax2.set_ylim(-2,102)
ax2.set_xlim(-2,30000)
ax2.set_xticks([0, 5000, 10000, 15000, 20000, 25000, 30000])

ax1.scatter(x=Dane_group_syn['Position'], y=Dane_group_syn['Sample_count'], marker='o', s=20, facecolors='#C44536', edgecolors='#933831', zorder=1)
ax1.scatter(x=Dane_group_nonsyn['Position'], y=Dane_group_nonsyn['Sample_count'], marker='o', s=20, facecolors='none', edgecolors='#933831', zorder=1)

ax2.scatter(x=MKE_group_syn['Position'], y=MKE_group_syn['Sample_count'], marker='o', s=20, facecolors='#457B9D', edgecolors='#305882', zorder=2)
ax2.scatter(x=MKE_group_nonsyn['Position'], y=MKE_group_nonsyn['Sample_count'], marker='o', s=20, facecolors='none', edgecolors='#305882', zorder=2)

fig.savefig("../figures/consensus_SNV_differences.pdf", bbox_inches='tight', dpi=300)

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ## metadata age stuff -- for UWHC only

# %%
Dane_all = pd.concat([pd.read_csv(f, sep='\t') for f in glob.glob("../data_derived/Dane/cleaned/*.csv")], ignore_index=True)
Dane_all = Dane_all[['sample', 'Position']]

metadata_age = pd.read_csv('../data_raw/UWHC_ages.csv', sep='\t')

metadata_age = metadata_age[['strain', 'age']]

metadata_age['strain'] = metadata_age['strain'].str.replace('/','_')

metadata_age_dict = dict(zip(metadata_age.strain, metadata_age.age))

Dane_all['ages'] = Dane_all['sample'].map(metadata_age_dict)

Dane_all

#
# Out:
#                  sample  Position  ages
# 0          USA_WI1_2020     17373    52
# 1     USA_WI-UW-46_2020       241    43
# 2     USA_WI-UW-46_2020      3037    43
# 3     USA_WI-UW-46_2020     11417    43
# 4     USA_WI-UW-46_2020     14073    43
# 5     USA_WI-UW-46_2020     14408    43
# 6     USA_WI-UW-46_2020     23403    43
# 7     USA_WI-UW-46_2020     23947    43
# 8     USA_WI-UW-78_2020       241    59
# 9     USA_WI-UW-78_2020       263    59
# 10    USA_WI-UW-78_2020      1191    59
# 11    USA_WI-UW-78_2020      3037    59
# 12    USA_WI-UW-78_2020     14408    59
# 13    USA_WI-UW-78_2020     20325    59
# 14    USA_WI-UW-78_2020     23403    59
# 15    USA_WI-UW-59_2020      8782    82
# 16    USA_WI-UW-59_2020     13019    82
# 17    USA_WI-UW-59_2020     16457    82
# 18    USA_WI-UW-59_2020     17747    82
# 19    USA_WI-UW-59_2020     17858    82
# 20    USA_WI-UW-59_2020     18060    82
# 21    USA_WI-UW-59_2020     28144    82
# 22    USA_WI-UW-67_2020      8782    42
# 23    USA_WI-UW-67_2020     16381    42
# 24    USA_WI-UW-67_2020     17877    42
# 25    USA_WI-UW-67_2020     20316    42
# 26    USA_WI-UW-67_2020     25500    42
# 27    USA_WI-UW-67_2020     28144    42
# 28    USA_WI-UW-67_2020     28878    42
# 29    USA_WI-UW-67_2020     29742    42
# ..                  ...       ...   ...
# 903  USA_WI-UW-150_2020      3037    48
# 904  USA_WI-UW-150_2020      6730    48
# 905  USA_WI-UW-150_2020     14408    48
# 906  USA_WI-UW-150_2020     18214    48
# 907  USA_WI-UW-150_2020     23403    48
# 908   USA_WI-UW-92_2020       241    59
# 909   USA_WI-UW-92_2020      1059    59
# 910   USA_WI-UW-92_2020      3037    59
# 911   USA_WI-UW-92_2020     14408    59
# 912   USA_WI-UW-92_2020     15760    59
# 913   USA_WI-UW-92_2020     23403    59
# 914   USA_WI-UW-92_2020     25563    59
# 915   USA_WI-UW-74_2020       241  0.25
# 916   USA_WI-UW-74_2020      1059  0.25
# 917   USA_WI-UW-74_2020      3037  0.25
# 918   USA_WI-UW-74_2020     14408  0.25
# 919   USA_WI-UW-74_2020     15760  0.25
# 920   USA_WI-UW-74_2020     23403  0.25
# 921   USA_WI-UW-74_2020     25563  0.25
# 922  USA_WI-UW-114_2020       241    36
# 923  USA_WI-UW-114_2020      3037    36
# 924  USA_WI-UW-114_2020     14330    36
# 925  USA_WI-UW-114_2020     14408    36
# 926  USA_WI-UW-114_2020     23403    36
# 927  USA_WI-UW-114_2020     27299    36
# 928  USA_WI-UW-114_2020     27989    36
# 929  USA_WI-UW-114_2020     28881    36
# 930  USA_WI-UW-114_2020     28882    36
# 931  USA_WI-UW-114_2020     28883    36
# 932  USA_WI-UW-114_2020     29148    36
#
# [933 rows x 3 columns]

# %%
Dane_ages_temp = Dane_all.groupby('Position')['ages'].apply(','.join)

Dane_ages = pd.DataFrame(Dane_ages_temp)

Dane_ages = Dane_ages['ages'].str.split(',',expand=True)

Dane_ages = Dane_ages.astype(float)

Dane_ages['mean'] = Dane_ages.mean(axis=1)
Dane_ages['std'] = Dane_ages.std(axis=1)

Dane_ages = Dane_ages[['mean', 'std']]

Dane_ages = Dane_ages.reset_index()

# Dane_ages.to_csv('/Users/katbraun/Desktop/ages.csv')

# %%
# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(12,8), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(2, 10)

ax1 = fig.add_subplot(gs[1,0:8])

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

ax1.set_xlabel('\n genome position', fontname='Arial', fontsize=12)
ax1.set_ylabel('average age', fontname='Arial', fontsize=12)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-2,102)
ax1.set_xlim(-2,30000)
ax1.set_xticks([0, 5000, 10000, 15000, 20000, 25000, 30000])

ax1.errorbar(Dane_ages['Position'], Dane_ages['mean'], yerr=Dane_ages['std'], fmt='.', zorder=0, lw=0.5, c='#933831')
ax1.scatter(x=Dane_ages['Position'], y=Dane_ages['mean'], marker='o', s=20, facecolors='#C44536', edgecolors='#933831', zorder=2)

fig.savefig("../figures/SNVs_vs_age.pdf", bbox_inches='tight', dpi=300)

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
Dane_all = pd.concat([pd.read_csv(f, sep='\t') for f in glob.glob("../data_derived/Dane/cleaned/*.csv")], ignore_index=True)
Dane_all = Dane_all[['sample', 'Position']]

metadata_age = pd.read_csv('../data_raw/UWHC_ages.csv', sep='\t')

metadata_age = metadata_age[['strain', 'age']]

metadata_age['strain'] = metadata_age['strain'].str.replace('/','_')

metadata_age_dict = dict(zip(metadata_age.strain, metadata_age.age))

Dane_all['ages'] = Dane_all['sample'].map(metadata_age_dict)

Dane_all = Dane_all.set_index('sample')

Dane_all = Dane_all.astype(float)

Dane_all['range'] = pd.cut(Dane_all.ages,[-1,19,44,64,89,100], labels=['0-19','20-44','45-64', '65-89', '≥90'])

Dane_all.groupby('range')['ages'].count().reset_index(name='Count').to_dict(orient='records')

# age bins

# "0 - 19"	1
# "20 - 44"	56
# "45 - 64"	35
# "65 - 89"	24
# "≥ 90"	2
# Out:
# [{'range': '0-19', 'Count': 7},
#  {'range': '20-44', 'Count': 424},
#  {'range': '45-64', 'Count': 297},
#  {'range': '65-89', 'Count': 183},
#  {'range': '≥90', 'Count': 22}]

# %%
import seaborn as sns

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(14,8), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(2, 12)

ax3 = fig.add_subplot(gs[0,8:12]) # beta-binomial estimates 

# get right of top and right frame of each subplot
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(True)
ax3.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax3.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax3.tick_params(axis = 'both', which = 'minor', labelsize = 10)


BB = pd.DataFrame({"":['0-19', '20-44', '45-64', '65-89', '≥90'], "SNV":[0.75, 45.44, 31.83, 19.61, 2.36], "age":[0.847, 47.45, 29.66, 20.34, 1.69]})
BB = pd.melt(BB, id_vars="", var_name="type", value_name="freq")

flatui = ['#0066A9', 'lightgrey', '#5BACCF', 'lightgrey', '#539648', 'lightgrey', '#C8C76F', 'lightgrey', '#E99F2E', 'lightgrey']
sns.set_palette(flatui)
sns.factorplot(x='', y='freq', data=BB, hue='type', kind='bar', ax=ax3, legend=None)

# edit the axes - ax3
ax3.set_title('', fontname='Arial', fontsize=14)
ax3.set_ylabel('% of consensus SNVs \n', fontname='Arial', fontsize=10)
ax3.set_xlabel('\n age bins', fontname='Arial', fontsize=10)
ax3.set_facecolor('white')
for tick in ax3.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax3.get_yticklabels():
    tick.set_fontname("Arial")
ax3.set_ylim(0,50)
ax3.set_yticks([0,10,20,30,40,50])

plt.xticks(rotation=45)

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("../figures/SNVS-per-age-bins.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
